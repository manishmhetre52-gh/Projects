# %%
text = """Python is one of the most popular programming languages in the world.
It is known for its simple syntax and readability.
Many beginners start their coding journey with Python.
It supports multiple programming paradigms.
Python is widely used in web development.
It is also heavily used in data science.
Machine learning engineers prefer Python for experimentation.
Automation scripts are commonly written in Python.
Python has a huge collection of libraries.
NumPy is used for numerical operations.
Pandas is used for data analysis.
Matplotlib is useful for data visualization.
Flask helps in building lightweight web apps.
Django is used for large-scale web development.
Python also supports object-oriented programming.
Functions make code reusable and clean.
Lambda functions are useful for short logic.
Exception handling helps avoid program crashes.
Logging is important for debugging applications.
File handling is one of the most useful concepts.
Text files can store logs and reports.
CSV files are often used for tabular data.
JSON is common for APIs and configurations.
Consistent practice improves coding skills.
Problem solving is the key to mastering Python.
Daily coding builds confidence and speed.
Understanding logic is more important than memorizing syntax.
Projects help connect all concepts together.
A strong Python foundation opens many career opportunities.
With patience and discipline, anyone can become a great programmer."""

# %%
with open("exercise.txt",'w') as f:
    f.write(text)

# %%
"""1. Write a Python program to read an entire text file."""
with open("exercise.txt",'r') as f:
    print(f.read())
# Out:
# Python is one of the most popular programming languages in the world.
# It is known for its simple syntax and readability.
# Many beginners start their coding journey with Python.
# It supports multiple programming paradigms.
# Python is widely used in web development.
# It is also heavily used in data science.
# Machine learning engineers prefer Python for experimentation.
# Automation scripts are commonly written in Python.
# Python has a huge collection of libraries.
# NumPy is used for numerical operations.
# Pandas is used for data analysis.
# Matplotlib is useful for data visualization.
# Flask helps in building lightweight web apps.
# Django is used for large-scale web development.
# Python also supports object-oriented programming.
# Functions make code reusable and clean.
# Lambda functions are useful for short logic.
# Exception handling helps avoid program crashes.
# Logging is important for debugging applications.
# File handling is one of the most useful concepts.
# ...

# %%
"""2. Write a Python program to read first n lines of a file."""
def read_first_n_lines(n,file_name):
    file = open(file_name,'r')
    for i in range(n):
        print(file.readline())
    file.close()

# %%
read_first_n_lines(10,"exercise.txt")
# Out:
# Python is one of the most popular programming languages in the world.
#
# It is known for its simple syntax and readability.
#
# Many beginners start their coding journey with Python.
#
# It supports multiple programming paradigms.
#
# Python is widely used in web development.
#
# It is also heavily used in data science.
#
# Machine learning engineers prefer Python for experimentation.
#
# Automation scripts are commonly written in Python.
#
# Python has a huge collection of libraries.
#
# NumPy is used for numerical operations.

# %%
"""3. Write a Python program to append text to a file and display the text."""
def append_text(string,filename):
    with open(filename,'a') as f:
        f.write(string)
    with open(filename,'r') as l:
        print(l.read())

# %%
append_text("\nHello","exercise.txt")
# Out:
# Python is one of the most popular programming languages in the world.
# It is known for its simple syntax and readability.
# Many beginners start their coding journey with Python.
# It supports multiple programming paradigms.
# Python is widely used in web development.
# It is also heavily used in data science.
# Machine learning engineers prefer Python for experimentation.
# Automation scripts are commonly written in Python.
# Python has a huge collection of libraries.
# NumPy is used for numerical operations.
# Pandas is used for data analysis.
# Matplotlib is useful for data visualization.
# Flask helps in building lightweight web apps.
# Django is used for large-scale web development.
# Python also supports object-oriented programming.
# Functions make code reusable and clean.
# Lambda functions are useful for short logic.
# Exception handling helps avoid program crashes.
# Logging is important for debugging applications.
# File handling is one of the most useful concepts.
# ...

# %%
"""4. Write a Python program to read last n lines of a file."""
def read_last_n_lines(n,filename):
    with open("exercise.txt",'r') as f:
        as_list = f.read().split('\n')
        last = as_list[-1:-(n+1):-1]
        print(" \n".join(last))

# %%
read_last_n_lines(10,"exercise.txt")
# Out:
# Hello
# With patience and discipline, anyone can become a great programmer.
# A strong Python foundation opens many career opportunities.
# Projects help connect all concepts together.
# Understanding logic is more important than memorizing syntax.
# Daily coding builds confidence and speed.
# Problem solving is the key to mastering Python.
# Consistent practice improves coding skills.
# JSON is common for APIs and configurations.
# CSV files are often used for tabular data.

# %%
"""5. Write a Python program to read a file line by line and store it into a list."""
def file_to_list(filename):
    with open(filename,'r') as f:
        as_list = f.read().split("\n")
        print(as_list)

# %%
file_to_list("exercise.txt")
# Out:
# ['Python is one of the most popular programming languages in the world.', 'It is known for its simple syntax and readability.', 'Many beginners start their coding journey with Python.', 'It supports multiple programming paradigms.', 'Python is widely used in web development.', 'It is also heavily used in data science.', 'Machine learning engineers prefer Python for experimentation.', 'Automation scripts are commonly written in Python.', 'Python has a huge collection of libraries.', 'NumPy is used for numerical operations.', 'Pandas is used for data analysis.', 'Matplotlib is useful for data visualization.', 'Flask helps in building lightweight web apps.', 'Django is used for large-scale web development.', 'Python also supports object-oriented programming.', 'Functions make code reusable and clean.', 'Lambda functions are useful for short logic.', 'Exception handling helps avoid program crashes.', 'Logging is important for debugging applications.', 'File handling is one of the most us
# ...

# %%
"""6. Write a Python program to read a file line by line store it into a variable."""
def file_to_var(filename):
    with open(filename,'r') as f:
        variable = f.read()
        return variable

# %%
data = file_to_var("exercise.txt")
print(data)
# Out:
# Python is one of the most popular programming languages in the world.
# It is known for its simple syntax and readability.
# Many beginners start their coding journey with Python.
# It supports multiple programming paradigms.
# Python is widely used in web development.
# It is also heavily used in data science.
# Machine learning engineers prefer Python for experimentation.
# Automation scripts are commonly written in Python.
# Python has a huge collection of libraries.
# NumPy is used for numerical operations.
# Pandas is used for data analysis.
# Matplotlib is useful for data visualization.
# Flask helps in building lightweight web apps.
# Django is used for large-scale web development.
# Python also supports object-oriented programming.
# Functions make code reusable and clean.
# Lambda functions are useful for short logic.
# Exception handling helps avoid program crashes.
# Logging is important for debugging applications.
# File handling is one of the most useful concepts.
# ...

# %%
import string

# %%
"""7. Write a python program to find the longest words."""
def find_longest_word(filename):
    with open(filename,'r') as f:
        as_list = f.read().split()
        max_len = 0
        longest_word = ""
        for word in as_list:
            word = word.strip(string.punctuation)
            if len(word) > max_len:
                max_len = len(word)
                longest_word = word
        print(longest_word)

# %%
find_longest_word("exercise.txt")
# Out:
# experimentation

# %%
"""8. Write a Python program to count the number of lines in a text file."""
def count_lines(filename):
    with open(filename,'r') as f:
        as_list = f.read().split("\n")
        print(len(as_list))

# %%
count_lines("exercise.txt")
# Out:
# 31

# %%
"""9. Write a Python program to count the frequency of words in a file."""
def count_words(filename,words):
    count = 0
    with open(filename,'r') as f:
        read_file = f.read()
        for word in read_file.split():
            if word == words:
                count += 1
        return count

# %%
count_words("exercise.txt","is")
# Out:
# 13

# %%
def count_indi_words(filename):
    with open(filename,'r') as f:
        lst = f.read().split()
        clean_lst = []
        for word in lst:
            word = word.strip(string.punctuation).lower()
            clean_lst.append(word)
        words = []
        for word in lst:
            word = word.strip(string.punctuation).lower()
            if word not in words:
                words.append(word)
        return {i:clean_lst.count(i)
        for i in words}

# %%
count_indi_words("exercise.txt")
# Out:
# {'python': 9,
#  'is': 13,
#  'one': 2,
#  'of': 3,
#  'the': 4,
#  'most': 2,
#  'popular': 1,
#  'programming': 3,
#  'languages': 1,
#  'in': 5,
#  'world': 1,
#  'it': 3,
#  'known': 1,
#  'for': 10,
#  'its': 1,
#  'simple': 1,
#  'syntax': 2,
#  'and': 6,
#  'readability': 1,
#  'many': 2,
#  'beginners': 1,
#  'start': 1,
#  'their': 1,
#  'coding': 3,
#  'journey': 1,
#  'with': 2,
#  'supports': 2,
#  'multiple': 1,
#  'paradigms': 1,
#  'widely': 1,
#  'used': 6,
#  'web': 3,
#  'development': 2,
#  'also': 2,
#  'heavily': 1,
#  'data': 4,
#  'science': 1,
#  'machine': 1,
#  'learning': 1,
#  'engineers': 1,
#  'prefer': 1,
#  'experimentation': 1,
#  'automation': 1,
#  'scripts': 1,
#  'are': 3,
#  'commonly': 1,
#  'written': 1,
#  'has': 1,
#  'a': 3,
#  'huge': 1,
#  'collection': 1,
#  'libraries': 1,
#  'numpy': 1,
#  'numerical': 1,
#  'operations': 1,
#  'pandas': 1,
#  'analysis': 1,
#  'matplotlib': 1,
#  'useful': 3,
#  'visualization': 1,
#  'flask': 1,
# ...

# %%
import os

# %%
"""10. Write a Python program to get the file size of a plain file."""
def get_file_size(filename):
   print(os.path.getsize(filename),"bytes")

# %%
get_file_size("exercise.txt")
# Out:
# 1477 bytes

# %%
import json

# %%
"""11. Write a Python program to write a list to a file."""
def list_in_file(filename,lst):
    with open(filename,'w') as f:
        json.dump(lst,f)
    print(f"{lst} has been added to {filename} succesfully")

# %%
list_in_file("exercise.json",[1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5] has been added to exercise.json succesfully

# %%
with open("exercise.json",'r') as f:
    json_data = json.load(f)
    print(json_data)
    print(type(json_data))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %%
"""12. Write a Python program to copy the contents of a file to another file ."""
def copy_file_to_file(file1,file2):
    data = None
    with open(file1,"r") as f1:
        data = f1.read()
    with open(file2,"w") as f2:
        f2.write(data)
    print(f"Data successfully copied from {file1} to {file2}")

# %%
copy_file_to_file("exercise.txt","exercise2.txt")
# Out:
# Data successfully copied from exercise.txt to exercise2.txt

# %%
with open("exercise2.txt",'r') as f:
    print(f.read())
# Out:
# Python is one of the most popular programming languages in the world.
# It is known for its simple syntax and readability.
# Many beginners start their coding journey with Python.
# It supports multiple programming paradigms.
# Python is widely used in web development.
# It is also heavily used in data science.
# Machine learning engineers prefer Python for experimentation.
# Automation scripts are commonly written in Python.
# Python has a huge collection of libraries.
# NumPy is used for numerical operations.
# Pandas is used for data analysis.
# Matplotlib is useful for data visualization.
# Flask helps in building lightweight web apps.
# Django is used for large-scale web development.
# Python also supports object-oriented programming.
# Functions make code reusable and clean.
# Lambda functions are useful for short logic.
# Exception handling helps avoid program crashes.
# Logging is important for debugging applications.
# File handling is one of the most useful concepts.
# ...

# %%
import random

# %%
"""13. Write a Python program to read a random line from a file."""
def read_random_line(filename):
    with open(filename,'r') as f:
        data = f.read().split("\n")
    pos = random.randint(0,len(data)-1)
    return str(data[pos])

# %%
def read_random_line_choice(filename):
    with open(filename,"r") as f:
        data = f.read().split("\n")
        return random.choice(data)

# %%
read_random_line("exercise.txt")
# Out:
# 'It supports multiple programming paradigms.'

# %%
read_random_line_choice("exercise.txt")
# Out:
# 'Automation scripts are commonly written in Python.'

# %%
"""14. Write a Python program to assess if a file is closed or not."""
def closed_or_not(filename):
    temp_file = open(filename,'r')
    print("Before closing:",temp_file.closed)
    temp_file.close()
    print("After closing:",temp_file.closed)

# %%
closed_or_not("exercise.txt")
# Out:
# Before closing: False
# After closing: True

# %%
"""15. Write a Python program that takes a text file as input and returns the number of words of a given text file."""
def count_tot_words(filename):
    with open(filename,'r') as f:
        data = f.read().split()
    return f"Total number of words: {len(data)}"

# %%
count_tot_words("exercise.txt")
# Out:
# 'Total number of words: 214'
